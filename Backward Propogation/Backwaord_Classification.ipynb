# %%
import numpy as np
import pandas as pd

# %%
df =pd.DataFrame([[8,8,1],[6,10,0],[5,5,0]],columns = ['cgpa','profile_score','lpa'])

# %%
df
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    1
# 1     6             10    0
# 2     5              5    0

# %%
def initialize_parameters(layer_dims):

  np.random.seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1, L):

    parameters['W' + str(l)] = np.ones((layer_dims[l-1], layer_dims[l]))*0.1
    parameters['b' + str(l)] = np.zeros((layer_dims[l], 1))


  return parameters

# %%
# Utility Functions
def sigmoid(Z):

  A = 1/(1+np.exp(-Z))

  return A

# %%
def linear_forward(A_prev, W, b):

  Z = np.dot(W.T, A_prev) + b

  A = sigmoid(Z)

  return A

# %%
# L-layer feed forward

def L_layer_forward(X, parameters):

  A = X
  L = len(parameters) // 2                  # number of layers in the neural network

  for l in range(1, L+1):
    A_prev = A
    Wl = parameters['W' + str(l)]
    bl = parameters['b' + str(l)]
    #print("A"+str(l-1)+": ", A_prev)
    #print("W"+str(l)+": ", Wl)
    #print("b"+str(l)+": ", bl)
    #print("--"*20)

    A = linear_forward(A_prev, Wl, bl)
    #print("A"+str(l)+": ", A)
    #print("**"*20)

  return A,A_prev

# %%
def update_parameters(parameters, y, y_hat, X):
  parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])
  parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])
  parameters['b2'][0][0] = parameters['b2'][0][0] + (0.0001 * (y - y_hat))

  parameters['W1'][0][0] = parameters['W1'][0][0] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0]*(1-sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])*X[0][0])
  parameters['W1'][0][1] = parameters['W1'][0][1] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0]*(1-sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])*X[1][0])
  parameters['b1'][0][0] = parameters['b1'][0][0] + (0.0001 * (y - y_hat)*parameters['W2'][0][0]*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0]*(1-sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0]))

  parameters['W1'][1][0] = parameters['W1'][1][0] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0]*(1-sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])*X[0][0])
  parameters['W1'][1][1] = parameters['W1'][1][1] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0]*(1-sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])*X[1][0])
  parameters['b1'][1][0] = parameters['b1'][1][0] + (0.0001 * (y - y_hat)*parameters['W2'][1][0]*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0]*(1-sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0]))

# %%
X = df[['cgpa', 'profile_score']].values[0].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# Loss for this student -  [0.61340263]
# /tmp/ipython-input-3899717768.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])
# /tmp/ipython-input-3899717768.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])
# ...

# %%
X = df[['cgpa', 'profile_score']].values[1].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# Loss for this student -  [0.61340263]
# /tmp/ipython-input-3899717768.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])
# /tmp/ipython-input-3899717768.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])
# ...

# %%
X = df[['cgpa', 'profile_score']].values[2].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

parameters
# Out:
# Loss for this student -  [0.62271118]
# /tmp/ipython-input-3899717768.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])
# /tmp/ipython-input-3899717768.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])
# ...

# %%
X = df[['cgpa', 'profile_score']].values[2].reshape(2,1) # Shape(no of features, no. of training example)
y = df[['lpa']].values[0][0]

# Parameter initialization
parameters = initialize_parameters([2,2,1])

y_hat = L_layer_forward(X,parameters)
y_hat = y_hat[0][0]

update_parameters(parameters,y,y_hat,X)

print('Loss for this student - ',-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))
# Out:
# Loss for this student -  [0.62271118]
# /tmp/ipython-input-3899717768.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][0][0] = parameters['W2'][0][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[0][0])
# /tmp/ipython-input-3899717768.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['W2'][1][0] = parameters['W2'][1][0] + (0.0001 * (y - y_hat)*sigmoid(np.dot(parameters['W1'], X) + parameters['b1'])[1][0])
# ...

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])
epochs = 50

for i in range(epochs):

  Loss = []

  for j in range(df.shape[0]):

    X = df[['cgpa', 'profile_score']].values[j].reshape(2,1) # Shape(no of features, no. of training example)
    y = df[['lpa']].values[j][0]

    # Parameter initialization


    y_hat = L_layer_forward(X,parameters)
    y_hat = y_hat[0][0]

    update_parameters(parameters,y,y_hat,X)

    Loss.append(-y*np.log(y_hat) - (1-y)*np.log(1-y_hat))

  print('Epoch - ',i+1,'Loss - ',np.array(Loss).mean())

parameters
# Out:
# Epoch -  1 Loss -  0.7207274042441619
# Epoch -  2 Loss -  0.7206999093789938
# Epoch -  3 Loss -  0.7206724249604098
# Epoch -  4 Loss -  0.7206449509837287
# Epoch -  5 Loss -  0.7206174874442718
# Epoch -  6 Loss -  0.7205900343373627
# Epoch -  7 Loss -  0.7205625916583269
# Epoch -  8 Loss -  0.7205351594024935
# Epoch -  9 Loss -  0.7205077375651928
# Epoch -  10 Loss -  0.7204803261417582
# Epoch -  11 Loss -  0.7204529251275248
# Epoch -  12 Loss -  0.7204255345178311
# Epoch -  13 Loss -  0.7203981543080172
# Epoch -  14 Loss -  0.7203707844934261
# Epoch -  15 Loss -  0.7203434250694022
# Epoch -  16 Loss -  0.7203160760312938
# Epoch -  17 Loss -  0.7202887373744508
# Epoch -  18 Loss -  0.7202614090942246
# Epoch -  19 Loss -  0.7202340911859711
# Epoch -  20 Loss -  0.7202067836450464
# Epoch -  21 Loss -  0.7201794864668104
# Epoch -  22 Loss -  0.7201521996466248
# Epoch -  23 Loss -  0.7201249231798541
# Epoch -  24 Loss -  0.7200976570618645
# ...
