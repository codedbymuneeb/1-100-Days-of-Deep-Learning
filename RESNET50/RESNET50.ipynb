# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
import numpy as np
from tensorflow.keras import models, layers

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
img_path ='/content/chair.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds =model.predict(x)
print('predicted:',decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# predicted: [('n03125729', 'cradle', np.float32(0.12769413)), ('n04485082', 'tripod', np.float32(0.08628739)), ('n03944341', 'pinwheel', np.float32(0.058851045))]

# %%
img_paths ='/content/DOG.jpg'
img = image.load_img(img_paths, target_size=(224, 224))
x =image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
predcit =model.predict(x)

print('predicted:',decode_predictions(predcit, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predicted: [('n02109961', 'Eskimo_dog', np.float32(0.78823084)), ('n02110185', 'Siberian_husky', np.float32(0.14704415)), ('n02110063', 'malamute', np.float32(0.060327236))]

# %%
img_path ='/content/BREAD.jpg'
img =image.load_img(img_path, target_size=(224, 224))
x =image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
predcit =model.predict(x)

print('predicted:',decode_predictions(predcit, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predicted: [('n07684084', 'French_loaf', np.float32(0.8709418)), ('n04442312', 'toaster', np.float32(0.09259689)), ('n07693725', 'bagel', np.float32(0.008177545))]

# %%
img_path ='/content/CAT.jpg'
img =image.load_img(img_path, target_size=(224, 224))
x =image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
predcit =model.predict(x)

print('predicted:',decode_predictions(predcit, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predicted: [('n02123159', 'tiger_cat', np.float32(0.3821717)), ('n02124075', 'Egyptian_cat', np.float32(0.14530274)), ('n02123045', 'tabby', np.float32(0.13208874))]

# %%
img_path ='/content/CAT1.jpg'
img =image.load_img(img_path, target_size=(224, 224))
x =image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
predcit =model.predict(x)

print('predicted:',decode_predictions(predcit, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predicted: [('n02123045', 'tabby', np.float32(0.4302212)), ('n02123159', 'tiger_cat', np.float32(0.39678118)), ('n02127052', 'lynx', np.float32(0.11613297))]

# %%
img_path ='/content/HUMAN.jpg'
img =image.load_img(img_path, target_size=(224, 224))
x =image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
predcit =model.predict(x)

print('predicted:',decode_predictions(predcit, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# predicted: [('n04350905', 'suit', np.float32(0.44364205)), ('n02786058', 'Band_Aid', np.float32(0.07214084)), ('n02883205', 'bow_tie', np.float32(0.06866909))]

# %%
img_path ='/content/PEOPLE.jpg'
img =image.load_img(img_path, target_size=(224, 224))
x =image.img_to_array(img)
x=np.expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
predcit =model.predict(x)

print('predicted:',decode_predictions(predcit, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# predicted: [('n04532106', 'vestment', np.float32(0.43957257)), ('n03388043', 'fountain', np.float32(0.08116833)), ('n02669723', 'academic_gown', np.float32(0.064775765))]
