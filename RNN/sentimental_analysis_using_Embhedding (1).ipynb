# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten
from keras.utils import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train.shape
# Out:
# (25000, 50)

# %%
model = Sequential()
model.add(Embedding(10000,output_dim=2))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1,activation='sigmoid'))
model.build(input_shape=(None, 50))
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_6 (Embedding)         │ (None, 50, 2)          │        20,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_6 (SimpleRNN)        │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,153 (82.63 KB)
#  Trainable params: 21,153 (82.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history =model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.5258 - loss: 0.6894 - val_accuracy: 0.7568 - val_loss: 0.5101
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7912 - loss: 0.4496 - val_accuracy: 0.7969 - val_loss: 0.4456
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8537 - loss: 0.3423 - val_accuracy: 0.7632 - val_loss: 0.4897
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8773 - loss: 0.2982 - val_accuracy: 0.7839 - val_loss: 0.4786
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8870 - loss: 0.2817 - val_accuracy: 0.7801 - val_loss: 0.5285

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Example custom review
review = ["This movie was absolutely amazing, I loved it!"]

# Tokenize aur pad karo (same tokenizer as training)
# You need to create a tokenizer object here since it's not available from the previous cells.
# Assuming the vocabulary size is 10000 based on the embedding layer.
tokenizer = Tokenizer(num_words=10000)

sequence = tokenizer.texts_to_sequences(review)
# Use the same maxlen as used for padding the training data (50)
padded = pad_sequences(sequence, maxlen=50)

# Predict
prediction = model.predict(padded)
print("Sentiment:", "Positive 😀" if prediction[0] > 0.5 else "Negative 😞")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# Sentiment: Positive 😀

# %%
REVIEW2 =['The movie was painfully slow and the acting was terrible']
tokenizer =Tokenizer(num_words=10000)
padded =pad_sequences(sequence,maxlen=50)
prediction = model.predict(padded)
print("Sentiment:", "Positive 😀" if prediction[0] > 0.5 else "Negative 😞")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Sentiment: Positive 😀
