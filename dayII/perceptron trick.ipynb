# %%
from sklearn.datasets import make_classification

import numpy as np
X,y =make_classification(n_samples=100, n_features=2,n_informative=1,n_redundant=0,
                         n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
X.shape
# Out:
# (100, 2)

# %%
import numpy as np

def step(x):
    return 1 if x >= 0 else 0

def perceptron(X, y):
    weights = np.ones(X.shape[1])  # shape: (n_features,)
    Ir = 0.1  # learning rate
    
    for i in range(1000):
        j = np.random.randint(0, X.shape[0])  # pick random sample
        y_hat = step(np.dot(X[j], weights))
        weights = weights + Ir * (y[j] - y_hat) * X[j]
    
    return weights[0], weights[1:]

# %%
  np.random.randint(0,100)
# Out:
# 20

# %%
y[49]
# Out:
# 0

# %%
np.dot(np.insert(X[37],0,1),[1,1,1])
# Out:
# 2.843765513760431

# %%
step(0.294)
# Out:
# 1

# %%
np.insert(X[37],0,1)
# Out:
# array([1.        , 0.67394805, 1.16981747])

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [-0.07620722]
# 0.12559491383956467

# %%
m = -(coef_[0])  # Or skip this if not applicable
b = -(intercept_ / coef_[0])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
