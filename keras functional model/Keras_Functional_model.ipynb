# %%
# # phlu h, neural network bna rhy thy linearlarity ;r hi kam kr rhy thy keras ka squential model
# ]#like CNN  ANN
# 1 -output
# 2- output
# - linear

# keras Functional model-Api

# %%
from keras.models import Model

# %%
model =Model(inputs =x,outputs =[output1,output2])

# %%
from keras.layers import *

# %%
x =Input(shape=(3,))

# %%
hidden1 =Dense(128,activation='relu')(x)

# %%
hidden2 =Dense(64,activation='relu')(hidden1)

# %%
output1 =Dense(1,activation='linear')(hidden2)
output2 =Dense(1,activation='linear')(hidden2)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 3)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │        512 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │      8,256 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1)         │         65 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True,show_layer_names=True)

# %%
from keras.models import Model
from keras.layers import *

# %%
InputA = Input(shape=(32,))
InputB = Input(shape=(128,))

# %%
# the fisrt branch operates the first output
x=Dense(8,activation='relu')(InputA)
x1=Dense(4,activation='relu')(x)

# %%
# the second branch operates the second input
y=Dense(64,activation='relu')(InputB)
y1=Dense(32,activation='relu')(y)
Y2=Dense(8,activation='relu')(y1)

# %%
# COMBINE THE OUTPUTS OF TWO BRANCHES
COMBINED = concatenate([x1,Y2])

# %%
#APPLY A FC LAYER AND THEN A REGRESSION PREDICTION ON THE COBINED OUTPUTS
z= Dense(2,activation='relu')(COMBINED)
z1=Dense(1,activation='linear')(z)

# %%
# OUR MODEL WILL ACCEPT THE INPUTS OF THE TWO BRANCHES AND THEN OUTPUT THE ZINGLE VALUE
model = Model(inputs=[InputA,InputB],outputs=z1)

# %%
from keras.utils import plot_model
plot_model(model)
